# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Rama Krishna\Desktop\Res_menu\restaurantmenuchanges.csv",
    na_values=[""],
    low_memory=False,
    on_bad_lines='skip'  # skips lines with incorrect number of columns
)

print(df.head())
print(df.shape)  # to see how many rows were successfully read
# Out:
#                      createdOn changeOperation       market     city  \
# 0  2022-10-27 23:07:19.0000000          Create  Houston, TX  Houston
# 1  2022-10-27 23:07:26.0000000          Delete  Houston, TX  Houston
# 2  2022-10-27 23:07:26.0000000          Delete  Houston, TX  Houston
# 3  2022-10-27 23:07:33.0000000          Delete  Houston, TX  Houston
# 4  2022-10-27 23:07:33.0000000          Delete  Houston, TX  Houston
#
#                   menuItemName  \
# 0   1% Low Fat Milk (110 Cals)
# 1  10-Piece Boneless Wing Meal
# 2   8-Piece Boneless Wing Meal
# 3                   LUNCH DUET
# 4                 FILET MIGNON
#
#                                  menuItemDescription menuItemCurrentPrice  \
# 0  As delicious as our sandwiches are, they are e...                $2.19
# 1                     Served with fries and a drink.               $14.19
# 2                     Served with fries and a drink.               $12.99
# ...

# %%
with open(r"C:\Users\Rama Krishna\Desktop\Res_menu\restaurantmenuchanges.csv", 'r', encoding='utf-8') as f:
    for i, line in enumerate(f):
        if len(line.split(',')) != 19:  # expected 19 columns
            print(f"Line {i}: {len(line.split(','))} columns")
# Out:
# Line 1: 34 columns
# Line 2: 38 columns
# Line 3: 38 columns
# Line 4: 36 columns
# Line 5: 36 columns
# Line 6: 36 columns
# Line 7: 36 columns
# Line 8: 36 columns
# Line 9: 36 columns
# Line 10: 36 columns
# Line 11: 36 columns
# Line 12: 36 columns
# Line 13: 36 columns
# Line 14: 36 columns
# Line 15: 36 columns
# Line 16: 26 columns
# Line 17: 26 columns
# Line 18: 26 columns
# Line 19: 26 columns
# Line 20: 31 columns
# Line 21: 31 columns
# Line 22: 30 columns
# Line 23: 29 columns
# Line 24: 32 columns
# Line 25: 29 columns
# Line 26: 35 columns
# Line 27: 34 columns
# Line 28: 33 columns
# Line 29: 30 columns
# Line 30: 40 columns
# Line 31: 38 columns
# Line 32: 36 columns
# Line 33: 27 columns
# Line 34: 36 columns
# Line 35: 26 columns
# Line 36: 26 columns
# Line 37: 26 columns
# Line 38: 34 columns
# Line 39: 26 columns
# Line 40: 29 columns
# Line 41: 26 columns
# Line 42: 26 columns
# Line 43: 26 columns
# Line 44: 26 columns
# Line 45: 26 columns
# ...

# %%
import pandas as pd

# Step 1: Read the file while skipping bad rows
df = pd.read_csv(
    r"C:\Users\Rama Krishna\Desktop\Res_menu\restaurantmenuchanges.csv",
    na_values=[""],
    low_memory=False,
    on_bad_lines='skip'  # skips malformed lines
)

# Step 2: Save the cleaned data to a new CSV file
df.to_csv(r"C:\Users\Rama Krishna\Desktop\Res_menu\restaurantmenuchanges_clean.csv", index=False)

print("Clean CSV saved successfully.")
# Out:
# Clean CSV saved successfully.
